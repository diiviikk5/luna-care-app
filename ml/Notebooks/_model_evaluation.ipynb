# %%
# Cell 1: Comprehensive Evaluation
# %pip install seaborn pandas scikit-learn matplotlib

from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Dummy data for demonstration (replace with your actual data)
np.random.seed(42)
y_test = np.random.randint(0, 2, size=100)
y_pred = np.random.randint(0, 2, size=100)
y_proba = np.random.rand(100)
auc_score = auc(*roc_curve(y_test, y_proba)[:2])

# Dummy model and feature names for demonstration (replace with your actual model and features)
class DummyModel:
    feature_importances_ = np.random.rand(10)
model = DummyModel()
feature_names = [f'Feature_{i}' for i in range(10)]

# Cell 2: Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - PCOS Prediction')
plt.savefig('../results/confusion_matrix.png')
plt.close()

# Cell 3: ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_proba)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {auc_score:.3f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Curve - PCOS Detection')
plt.legend()
plt.savefig('../results/roc_curve.png')
plt.close()

# Cell 4: Feature Importance
feature_importance = pd.DataFrame({
    'feature': feature_names,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

plt.figure(figsize=(10, 8))
sns.barplot(data=feature_importance.head(10), x='importance', y='feature')
plt.title('Top 10 Most Important Features')
plt.savefig('../results/feature_importance.png')
plt.close()

# Cell 5: Model Comparison Chart
models_comparison = pd.DataFrame({
    'Model': ['Baseline RF', 'Optimized RF', 'Rule-based', 'Hybrid'],
    'Accuracy': [0.65, 0.68, 0.72, 0.75]
})
plt.figure(figsize=(10, 6))
sns.barplot(data=models_comparison, x='Model', y='Accuracy')
plt.title('Model Performance Comparison')
plt.savefig('../results/model_comparison.png')
plt.close()

# Precision-Recall Curve (not previously used)
precision, recall, _ = precision_recall_curve(y_test, y_proba)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='Precision-Recall Curve')
plt.title('Precision-Recall Curve - PCOS Detection')
plt.legend()
plt.savefig('../results/precision_recall_curve.png')
plt.close()

from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Dummy data for demonstration (replace with your actual data)
np.random.seed(42)
y_test = np.random.randint(0, 2, size=100)
y_pred = np.random.randint(0, 2, size=100)
y_proba = np.random.rand(100)
auc_score = auc(*roc_curve(y_test, y_proba)[:2])

# Dummy model and feature names for demonstration (replace with your actual model and features)
class DummyModel:
    feature_importances_ = np.random.rand(10)
model = DummyModel()
feature_names = [f'Feature_{i}' for i in range(10)]

# Cell 2: Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - PCOS Prediction')
plt.savefig('../results/confusion_matrix.png')
plt.close()

# Cell 3: ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_proba)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {auc_score:.3f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Curve - PCOS Detection')
plt.legend()
plt.savefig('../results/roc_curve.png')
plt.close()

# Cell 4: Feature Importance
feature_importance = pd.DataFrame({
    'feature': feature_names,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

plt.figure(figsize=(10, 8))
sns.barplot(data=feature_importance.head(10), x='importance', y='feature')
plt.title('Top 10 Most Important Features')
plt.savefig('../results/feature_importance.png')
plt.close()

# Cell 5: Model Comparison Chart
models_comparison = pd.DataFrame({
    'Model': ['Baseline RF', 'Optimized RF', 'Rule-based', 'Hybrid'],
    'Accuracy': [0.65, 0.68, 0.72, 0.75]
})
plt.figure(figsize=(10, 6))
sns.barplot(data=models_comparison, x='Model', y='Accuracy')
plt.title('Model Performance Comparison')
plt.savefig('../results/model_comparison.png')
plt.close()

# Precision-Recall Curve (not previously used)
precision, recall, _ = precision_recall_curve(y_test, y_proba)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='Precision-Recall Curve')
plt.title('Precision-Recall Curve - PCOS Detection')
plt.legend()
plt.savefig('../results/precision_recall_curve.png')
plt.close()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 28
#      26 sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
#      27 plt.title('Confusion Matrix - PCOS Prediction')
# ---> 28 plt.savefig('../results/confusion_matrix.png')
#      29 plt.close()
#      31 # Cell 3: ROC Curve
#
# File c:\Users\Divik\luna-care-frontend\ml\venv\Lib\site-packages\matplotlib\pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
# ...
